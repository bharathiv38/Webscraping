# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
Q4

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "http://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@id='sc.keyword']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c8757918eef56012aaf0f822ad00232c", element="2b3ef6ad-cb27-4b47-8a4f-a53791d4c4fb")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc=driver.find_element_by_xpath("//input[@id='sc.location']")
search_loc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c8757918eef56012aaf0f822ad00232c", element="159be276-2c30-4452-b2be-63133b4cf9eb")>

# %%
search_loc.send_keys("Noida(India)")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_btn.click()

# %%
from selenium import webdriver
import time

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='d-flex justify-content-between align-items-start']"):
        company_name.append(j.text)
    time.sleep(5)

# %%
company_name
# Out:
# ['Barclays',
#  'White Vectors',
#  'Applicate IT Solutions Pvt. Ltd.',
#  'Applicate IT Solutions Private Limited',
#  'Data Patterns',
#  'MediGence',
#  'Urban Company',
#  'Algo8 AI Pvt. Ltd.',
#  'Wobb.ai',
#  'Innovacer',
#  'Biz2Credit Inc',
#  'Ginger Webs Pvt. Ltd.',
#  'Scymes Services Pvt. ltd',
#  'MasterCard',
#  'Crowe',
#  'Ori',
#  'Salasar New Age Technologies',
#  'Amploy',
#  'KVCH',
#  'NatWest Group',
#  'Insta Admission Private Limited',
#  'MobiKwik',
#  'IElevate Institute',
#  'CarDekho',
#  'Siemens Technology and Services Private Limited',
#  'Donaldson',
#  'Genpact',
#  'Bulkbyte Company',
#  'ADCI - Haryana',
#  'Transorg Analytics',
#  'Barclays',
#  'White Vectors',
#  'Applicate IT Solutions Pvt. Ltd.',
#  'Applicate IT Solutions Private Limited',
#  'Data Patterns',
#  'MediGence',
#  'Urban Company',
#  'Algo8 AI Pvt. Ltd.',
#  'Wobb.ai',
#  'Innovacer',
#  'Biz2Credit Inc',
#  'Ginger Webs Pvt. Ltd.',
#  'Scymes Services Pvt. ltd',
# ...

# %%
location_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='css-11d3uq0 e1rrn5ka2']"):
        location_name.append(j.text)
    time.sleep(5)

# %%
location_name
# Out:
# ['New Delhi\n1d',
#  'New Delhi',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Gurgaon\n7d',
#  'Noida',
#  'New Delhi',
#  'Noida\nHiring Surge\n10d',
#  'Noida\nEasy Apply\n30d+',
#  'Noida\n28d',
#  'Noida\nEasy Apply\n7d',
#  'Gurgaon\n8d',
#  'Noida\n30d+',
#  'Noida',
#  'Noida\n30d+',
#  'New Delhi',
#  'Noida',
#  'New Delhi\n30d+',
#  'New Delhi',
#  'Gurgaon\n24d',
#  'Preet Vihar',
#  'Gurgaon\n30d+',
#  'Gurgaon\n21d',
#  'Gurgaon\n30d+',
#  'Gurgaon\n1d',
#  'Noida',
#  'Gurgaon\n22d',
#  'Gurgaon\n30d+',
#  'New Delhi\n1d',
#  'New Delhi',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Gurgaon\n7d',
#  'Noida',
#  'New Delhi',
#  'Noida\nHiring Surge\n10d',
#  'Noida\nEasy Apply\n30d+',
#  'Noida\n28d',
#  'Noida\nEasy Apply\n7d',
#  'Gurgaon\n8d',
#  'Noida\n30d+',
#  'Noida',
#  'Noida\n30d+',
#  'New Delhi',
#  'Noida',
#  'New Delhi\n30d+',
#  'New Delhi',
#  'Gurgaon\n24d',
#  'Preet Vihar',
#  'Gurgaon\n30d+',
#  'Gurgaon\n21d',
# ...

# %%
jobpostdays_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']"):
        jobpostdays_tags.append(j.text)
    time.sleep(5)

# %%
jobpostdays_tags
# Out:
# ['1d',
#  '2d',
#  '3d',
#  '2d',
#  '24d',
#  '2d',
#  '7d',
#  '21d',
#  '15d',
#  '10d',
#  '30d+',
#  '28d',
#  '7d',
#  '8d',
#  '30d+',
#  '24h',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '7d',
#  '24d',
#  '4d',
#  '30d+',
#  '21d',
#  '30d+',
#  '1d',
#  '6d',
#  '22d',
#  '30d+',
#  '1d',
#  '2d',
#  '3d',
#  '2d',
#  '24d',
#  '2d',
#  '7d',
#  '21d',
#  '15d',
#  '10d',
#  '30d+',
#  '28d',
#  '7d',
#  '8d',
#  '30d+',
#  '24h',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '7d',
#  '24d',
#  '4d',
#  '30d+',
#  '21d',
#  '30d+',
#  '1d',
#  '6d',
#  '22d',
#  '30d+',
#  '1d',
#  '2d',
#  '3d',
#  '2d',
#  '24d',
#  '2d',
#  '7d',
#  '21d',
#  '15d',
#  '10d',
#  '30d+',
#  '28d',
#  '7d',
#  '8d',
#  '30d+',
#  '24h',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '7d',
#  '24d',
#  '4d',
#  '30d+',
#  '21d',
#  '30d+',
#  '1d',
#  '6d',
#  '22d',
#  '30d+',
#  '1d',
#  '2d',
#  '3d',
#  '2d',
#  '24d',
#  '2d',
#  '7d',
#  '21d',
#  '15d',
#  '10d',
#  '30d+',
# ...

# %%
df=pd.DataFrame({"Company_name":company_name[0:10],"location_name":location_name[0:10],"jobpostdays_tags":jobpostdays_tags[0:10]
                })

df.head(10)
# Out:
#                              Company_name             location_name  \
# 0                                Barclays             New Delhi\n1d
# 1                           White Vectors                 New Delhi
# 2        Applicate IT Solutions Pvt. Ltd.                   Gurgaon
# 3  Applicate IT Solutions Private Limited                   Gurgaon
# 4                           Data Patterns                     Noida
# 5                               MediGence                     Noida
# 6                           Urban Company               Gurgaon\n7d
# 7                      Algo8 AI Pvt. Ltd.                     Noida
# 8                                 Wobb.ai                 New Delhi
# 9                               Innovacer  Noida\nHiring Surge\n10d
#
#   jobpostdays_tags
# 0               1d
# 1               2d
# 2               3d
# 3               2d
# 4              24d
# 5               2d
# 6               7d
# 7              21d
# 8              15d
# ...

# %% [markdown]
# Q5: Write a python program to scrape the salary data for Data Scientist designation in Noida location. You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary. The above task will be, done as shown in the below steps:
#
# first get the webpage https://www.glassdoor.co.in/Salaries/index.htm
# Enter “Data Scientist” in Job title field and “Noida” in location field.
# Click the search button.
# After that you will land on the below page You have to scrape whole data from this webpage
# Scrape data for first 10 companies. Scrape the min salary, max salary, company name, Average salary and rating of the company. 6.Store the data in a dataframe. Note that all of the above steps have to be done by coding only and not manually

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "http://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@id='sc.keyword']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="bad18e15-ec28-4205-97d5-9114770fd6eb")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc=driver.find_element_by_xpath("//input[@id='sc.location']")
search_loc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="cdbfad58-b6b9-4f75-9c89-40eef103aebd")>

# %%
search_loc.send_keys("Noida(India)")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_btn.click()

# %%
from selenium import webdriver
import time

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='d-flex justify-content-between align-items-start']"):
        company_name.append(j.text)
    time.sleep(5)

# %%
company_name
# Out:
# ['Bechtel',
#  'Salesforce',
#  'Ericsson',
#  'Crowe',
#  'MobiKwik',
#  'Priority Vendor',
#  'Lantern Digital Services',
#  'Biz2Credit Inc',
#  'Siemens Technology and Services Private Limited',
#  'Gauge Data Solutions',
#  'Ally wiredsoft solutions (P) ltd',
#  'Techlive',
#  'Data Patterns',
#  'NatWest Group',
#  'Novo',
#  'Innovacer',
#  'WishFin',
#  'xtLytics',
#  'Algoscale',
#  'SearchUrCollege',
#  'Salasar New Age Technologies',
#  'MasterCard',
#  'Barclays',
#  'Team Computers',
#  'ADCI - Haryana',
#  'Ank Aha',
#  'Analytics Vidhya',
#  'Profisor Services',
#  'Dürr Somac GmbH',
#  'White Vectors',
#  'ESRI, Inc.',
#  'Mahajan Imaging',
#  'Bechtel',
#  'Salesforce',
#  'Ericsson',
#  'Crowe',
#  'MobiKwik',
#  'Priority Vendor',
#  'Lantern Digital Services',
#  'Biz2Credit Inc',
#  'Siemens Technology and Services Private Limited',
#  'Gauge Data Solutions',
#  'Ally wiredsoft solutions (P) ltd',
#  'Techlive',
#  'Data Patterns',
#  'NatWest Group',
#  'Novo',
# ...

# %%
location_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='d-flex flex-wrap css-11d3uq0 e1rrn5ka2']"):
        location_name.append(j.text)
    time.sleep(5)

# %%
location_name
# Out:
# ['New Delhi\nActively Hiring\n24h',
#  'New Delhi',
#  'Noida',
#  'Noida\nHOT\n8d',
#  'Gurgaon',
#  'Noida',
#  'Noida\nNew\n2d',
#  'Noida\nEasy Apply\n17d',
#  'Gurgaon\nHOT\n21d',
#  'Noida\n8d',
#  'Noida',
#  'Noida\n14d',
#  'Noida',
#  'New Delhi\nNew\n24h',
#  'Gurgaon',
#  'Noida\nHiring Surge\n14d',
#  'Noida\n19d',
#  'Noida\n22d',
#  'Noida',
#  'Noida\n8d',
#  'Noida\n22d',
#  'Gurgaon',
#  'New Delhi\n1d',
#  'New Delhi',
#  'Gurgaon',
#  'New Delhi',
#  'Gurgaon\n8d',
#  'Gurgaon\n8d',
#  'Noida\n27d',
#  'New Delhi\nEasy Apply\n2d',
#  'New Delhi',
#  'New Delhi\n8d',
#  'New Delhi\nActively Hiring\n24h',
#  'New Delhi',
#  'Noida',
#  'Noida\nHOT\n8d',
#  'Gurgaon',
#  'Noida',
#  'Noida\nNew\n2d',
#  'Noida\nEasy Apply\n17d',
#  'Gurgaon\nHOT\n21d',
#  'Noida\n8d',
#  'Noida',
#  'Noida\n14d',
#  'Noida',
#  'New Delhi\nNew\n24h',
#  'Gurgaon',
#  'Noida\nHiring Surge\n14d',
#  'Noida\n19d',
#  'Noida\n22d',
#  'Noida',
#  'Noida\n8d',
#  'Noida\n22d',
# ...

# %%
salary=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='css-nq3w9f pr-xxsm']"):
        salary.append(j.text)
    time.sleep(5)

# %%
salary
# Out:
# ['₹362K - ₹394K (Glassdoor Est.)',
#  '₹474K - ₹957K (Glassdoor Est.)',
#  '₹970K - ₹1,000K (Glassdoor Est.)',
#  '₹300K - ₹850K (Glassdoor Est.)',
#  '₹500K - ₹776K (Glassdoor Est.)',
#  '₹500K - ₹816K (Glassdoor Est.)',
#  '₹500K - ₹800K (Glassdoor Est.)',
#  '₹669K - ₹720K (Glassdoor Est.)',
#  '₹729K - ₹909K (Glassdoor Est.)',
#  '₹275K - ₹400K (Glassdoor Est.)',
#  '₹618K - ₹868K (Glassdoor Est.)',
#  '₹500K - ₹715K (Glassdoor Est.)',
#  '₹450K - ₹900K (Glassdoor Est.)',
#  '₹362K - ₹394K (Glassdoor Est.)',
#  '₹474K - ₹957K (Glassdoor Est.)',
#  '₹970K - ₹1,000K (Glassdoor Est.)',
#  '₹300K - ₹850K (Glassdoor Est.)',
#  '₹500K - ₹776K (Glassdoor Est.)',
#  '₹500K - ₹816K (Glassdoor Est.)',
#  '₹500K - ₹800K (Glassdoor Est.)',
#  '₹669K - ₹720K (Glassdoor Est.)',
#  '₹729K - ₹909K (Glassdoor Est.)',
#  '₹275K - ₹400K (Glassdoor Est.)',
#  '₹618K - ₹868K (Glassdoor Est.)',
#  '₹500K - ₹715K (Glassdoor Est.)',
#  '₹450K - ₹900K (Glassdoor Est.)',
# ...

# %%
rating_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='css-19pjha7 e1cjmv6j1']"):
        rating_tags.append(j.text)
    time.sleep(5)

# %%
rating_tags
# Out:
# ['4.0',
#  '4.5',
#  '4.1',
#  '3.8',
#  '4.0',
#  '3.7',
#  '3.5',
#  '3.9',
#  '4.1',
#  '3.0',
#  '5.0',
#  '3.1',
#  '3.9',
#  '3.8',
#  '3.8',
#  '3.8',
#  '4.3',
#  '4.0',
#  '4.1',
#  '4.3',
#  '4.0',
#  '3.9',
#  '4.5',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.5',
#  '4.1',
#  '3.8',
#  '4.0',
#  '3.7',
#  '3.5',
#  '3.9',
#  '4.1',
#  '3.0',
#  '5.0',
#  '3.1',
#  '3.9',
#  '3.8',
#  '3.8',
#  '3.8',
#  '4.3',
#  '4.0',
#  '4.1',
#  '4.3',
#  '4.0',
#  '3.9',
#  '4.5',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.5',
#  '4.1',
#  '3.8',
#  '4.0',
#  '3.7',
#  '3.5',
#  '3.9',
#  '4.1',
#  '3.0',
#  '5.0',
#  '3.1',
#  '3.9',
#  '3.8',
#  '3.8',
#  '3.8',
#  '4.3',
#  '4.0',
#  '4.1',
#  '4.3',
#  '4.0',
#  '3.9',
#  '4.5',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.5',
#  '4.1',
#  '3.8',
#  '4.0',
#  '3.7',
#  '3.5',
#  '3.9',
#  '4.1',
#  '3.0',
#  '5.0',
#  '3.1',
#  '3.9',
#  '3.8',
#  '3.8',
#  '3.8',
#  '4.3',
#  '4.0',
#  '4.1',
#  '4.3',
#  '4.0',
#  '3.9',
#  '4.5',
#  '4.0',
#  '4.0',
# ...

# %%
avg_salary=[]

# %%
a=driver.find_elements_by_xpath("//div[@class='css-nq3w9f pr-xxsm']")
a
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="8da4670b-880b-433d-8d21-5b94aead77b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="72e7f617-35f2-4e83-a018-a601621daf4d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="30a9c850-e967-4ac5-aa00-c4823433d96c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="d18c3f79-004f-415e-bf7e-f3b4f03d27a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="f1f8aca6-126d-4c68-89e6-6e07417825f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="60aa6ea5cfabd1baf02b85e933d21d9c", element="07370648-925b-41d1-ba5d-f523eb5045e9")>,
# ...

# %%
for i in a:
    title=i.text
    avg_salary.append(title)
avg_salary[0:10]
# Out:
# ['₹362K - ₹394K (Glassdoor Est.)',
#  '₹474K - ₹957K (Glassdoor Est.)',
#  '₹970K - ₹1,000K (Glassdoor Est.)',
#  '₹300K - ₹850K (Glassdoor Est.)',
#  '₹500K - ₹776K (Glassdoor Est.)',
#  '₹500K - ₹816K (Glassdoor Est.)',
#  '₹500K - ₹800K (Glassdoor Est.)',
#  '₹669K - ₹720K (Glassdoor Est.)',
#  '₹729K - ₹909K (Glassdoor Est.)',
#  '₹275K - ₹400K (Glassdoor Est.)']

# %%
df=pd.DataFrame({"Company_name":company_name[0:10],"location_name":location_name[0:10],"salary":salary[0:10],"rating_tags":rating_tags[0:10],"avg_salary":avg_salary[0:10]
                })

df.head(10)
# Out:
#                                       Company_name  \
# 0                                          Bechtel
# 1                                       Salesforce
# 2                                         Ericsson
# 3                                            Crowe
# 4                                         MobiKwik
# 5                                  Priority Vendor
# 6                         Lantern Digital Services
# 7                                   Biz2Credit Inc
# 8  Siemens Technology and Services Private Limited
# 9                             Gauge Data Solutions
#
#                      location_name                            salary  \
# 0  New Delhi\nActively Hiring\n24h    ₹362K - ₹394K (Glassdoor Est.)
# 1                        New Delhi    ₹474K - ₹957K (Glassdoor Est.)
# 2                            Noida  ₹970K - ₹1,000K (Glassdoor Est.)
# 3                   Noida\nHOT\n8d    ₹300K - ₹850K (Glassdoor Est.)
# ...

# %% [markdown]
# Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# 4. Discount %
# The attributes which you have to scrape is ticked marked in the below image.
# To
#
# To scrape the data you have to go through following steps:
# 1. Go to flipkart webpage by url https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. after that you will reach to a webpage having a lot of sunglasses. From this page you can scrap the required data as usual.
# 4. after scraping data from the first page, go to the “Next” Button at the bottom of the page , then click on it
# 5. Now scrape data from this page as usual
# 6. repeat this until you get data for 100 sunglasses.
# Note that all of the above steps have to be done by coding only and not manually.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
search_field = driver.find_element_by_xpath("//input[@class='_3704LK']")
search_field
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3c5df691c17beeb9a392068c46ebf612", element="8a833a3a-f809-4922-a6a9-dae29416b1d7")>

# %%
search_field.send_keys("Sunglasses")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn.click()

# %%
brand_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand_tags.append(j.text)
    time.sleep(5)

# %%
brand_tags
# Out:
# ['LIZA ANGEL',
#  'Fravy',
#  'Fastrack',
#  'kingsunglasses',
#  'PIRASO',
#  'PHENOMENAL',
#  'GANSTA',
#  'AISLIN',
#  'Silver Kartz',
#  'DEIXELS',
#  'hipe',
#  'Fravy',
#  'Singco India',
#  'ROZZETTA CRAFT',
#  'HIPPON',
#  'Dannilo',
#  'IRUS by IDEE',
#  'Singco',
#  'NuVew',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Flizz',
#  'Wrogn',
#  'VINCENT CHASE',
#  'Fravy',
#  'Poland',
#  'United Colors of Benetton',
#  'ROYAL SON',
#  'Badfella',
#  'FOSSIL',
#  'IDEE',
#  'elegante',
#  'AISLIN',
#  'elegante',
#  'Fastrack',
#  'ROYAL SON',
#  'kingsunglasses',
#  'PHENOMENAL',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'LIZA ANGEL',
#  'Fravy',
#  'Fastrack',
#  'kingsunglasses',
#  'PIRASO',
#  'PHENOMENAL',
#  'GANSTA',
#  'AISLIN',
#  'Silver Kartz',
#  'DEIXELS',
#  'hipe',
#  'Fravy',
#  'Singco India',
#  'ROZZETTA CRAFT',
#  'HIPPON',
#  'Dannilo',
#  'IRUS by IDEE',
#  'Singco',
#  'NuVew',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Flizz',
#  'Wrogn',
#  'VINCENT CHASE',
# ...

# %%
price_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        price_tags.append(j.text)
    time.sleep(5)

# %%
price_tags
# Out:
# ['₹251',
#  '₹339',
#  '₹758',
#  '₹299',
#  '₹237',
#  '₹399',
#  '₹284',
#  '₹498',
#  '₹246',
#  '₹213',
#  '₹303',
#  '₹289',
#  '₹236',
#  '₹499',
#  '₹251',
#  '₹284',
#  '₹606',
#  '₹331',
#  '₹215',
#  '₹664',
#  '₹217',
#  '₹399',
#  '₹676',
#  '₹1,179',
#  '₹299',
#  '₹162',
#  '₹1,405',
#  '₹664',
#  '₹269',
#  '₹1,820',
#  '₹1,031',
#  '₹449',
#  '₹545',
#  '₹199',
#  '₹513',
#  '₹749',
#  '₹349',
#  '₹399',
#  '₹404',
#  '₹664',
#  '₹251',
#  '₹339',
#  '₹758',
#  '₹299',
#  '₹237',
#  '₹399',
#  '₹284',
#  '₹498',
#  '₹246',
#  '₹213',
#  '₹303',
#  '₹289',
#  '₹236',
#  '₹499',
#  '₹251',
#  '₹284',
#  '₹606',
#  '₹331',
#  '₹215',
#  '₹664',
#  '₹217',
#  '₹399',
#  '₹676',
#  '₹1,179',
#  '₹299',
#  '₹162',
#  '₹1,405',
#  '₹664',
#  '₹269',
#  '₹1,820',
#  '₹1,031',
#  '₹449',
#  '₹545',
#  '₹199',
#  '₹513',
#  '₹749',
#  '₹349',
#  '₹399',
#  '₹404',
#  '₹664',
#  '₹251',
#  '₹339',
#  '₹758',
#  '₹299',
#  '₹237',
#  '₹399',
#  '₹284',
#  '₹498',
#  '₹246',
# ...

# %%
product_description=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//a[@class='IRpwTa _2-ICcC']"):
        product_description.append(j.text)
    time.sleep(5)

# %%
product_description
# Out:
# ['UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
#  'Gradient, Night Vision, Riding Glasses Round, Oval Sung...',
#  'UV Protection, Mirrored, Riding Glasses Retro Square Su...',
# ...

# %%
discount_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        discount_tags.append(j.text)
    time.sleep(5)

# %%
discount_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  'PRICE',
#  '?',
#  '1400 MORE',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 40 of 88,172 results for "Sunglasses"',
#  'Sunglasses',
#  'Sort By',
#  'Ad',
#  '68% off',
#  'Size',
#  'Ad',
#  '83% off',
#  'Size',
#  '₹141 off',
#  '',
#  '88% off',
#  'Size',
#  '85% off',
#  '80% off',
#  '85% off',
#  'Ad',
#  '67% off',
#  '83% off',
#  '82% off',
#  '84% off',
#  'Ad',
#  '80% off',
#  '84% off',
#  '77% off',
#  '79% off',
#  'Ad',
#  '81% off',
#  '52% off',
#  '83% off',
#  '72% off',
#  'Ad',
#  '66% off',
#  '78% off',
#  '81% off',
#  '73% off',
#  'Ad',
#  '41% off',
#  '80% off',
#  '67% off',
#  '65% off',
#  'Ad',
#  '55% off',
#  '73% off',
#  '58% off',
#  '65% off',
#  'Ad',
#  '70% off',
#  '64% off',
#  '80% off',
#  '₹286 off',
#  'Ad',
#  '62% off',
# ...

# %%
df=pd.DataFramedf=pd.DataFrame({"brand_tags":brand_tags[0:100],"price_tags":price_tags[0:100],"discount_tags":discount_tags[0:100],"product_description":product_description[0:100]
                })

df.head(100)
# Out:
#         brand_tags price_tags     discount_tags  \
# 0       LIZA ANGEL       ₹251              Plus
# 1            Fravy       ₹339              Cart
# 2         Fastrack       ₹758       Electronics
# 3   kingsunglasses       ₹299  TVs & Appliances
# 4           PIRASO       ₹237               Men
# ..             ...        ...               ...
# 95         Dannilo       ₹284    &6,342 Reviews
# 96    IRUS by IDEE       ₹606                 &
# 97          Singco       ₹331     6,342 Reviews
# 98           NuVew       ₹215          ₹141 off
# 99       ROYAL SON       ₹664
#
#                                   product_description
# 0   UV Protection, Mirrored, Riding Glasses Retro ...
# 1   Gradient, Night Vision, Riding Glasses Round, ...
# 2   UV Protection, Mirrored, Riding Glasses Retro ...
# 3   Gradient, Night Vision, Riding Glasses Round, ...
# 4   UV Protection, Mirrored, Riding Glasses Retro ...
# ..                                                ...
# ...
